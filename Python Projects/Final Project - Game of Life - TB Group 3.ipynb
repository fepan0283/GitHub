# %%
# Welcome to our group project - The Game of Life!

# Creators: TB Group 3:
#.          Niklas Knüpfer (50706)
#           Felix Pan (50391)
#           Maximilian Zimmer (49372)

# The vision for our project was to create the Game of Life, the well-known board game with our own interpretation. We tackled
# the project in the following way: First, we created the actual game loop. The players move around the board that consist of 17 
# fields. Second, we created an action field for every field that the players arrive on, triggering some kind of event that 
# impacts their money balance, job, or education (e.g. "You play lotto. You win 10.000 EUR"). Third, we created some decision
# fields where the player interacts with code. Decisions affect the following fields and the outcome of the game. Lastly, we 
# created some functions like the selection of number of players and name creation. 
# In the end a winner is determined depending on the final balance of the player.

# The following section contains the activities that are called up as soon as a player 
# moves to the corresponding field.
# Each field is stored in the dictionary 'field_dic'. The key of each field is the associated 
# function that will be called subsequently.
# The action fields describe various situations that can occur in the course of life and 
# confront the player with decision-making.

# Note: please run all three fields to play the game

# %%
# ALL DECISION FIELD DEFINITIONS

# 1. choose education
def choose_education(player):
    print("You have to make a choice now", player.name)
    education_question = input("Do you want to go to university? A. yes, B: no")
    if education_question == "A":
        player.university = "yes"
    else:
        player.university = "no"

# 2. choose job
#players choose the job they want to pursure, depending on their previous education

#available jobs

university_jobs_dictionary = {
    "teacher": 40000,
    "lawyer": 110000,
    "manager": 100000,
    "mechanical engineer": 80000,
    "software engineer":90000,
    "doctor":120000,
    "architct":60000,
    "biologist":50000,
    "pilot": 85000,
    "president": 130000
    
}

no_university_jobs_dictionary ={
    
    "policeman, policewoman": 35000,
    "painter": 30000,
    "nurse": 30000,
    "actor": 110000,
    "singer":150000,
    "bank employee": 28000,
    "restaurant owner": 60000,
    "electrician": 32000,
    "realtor": 60000,
    "physiotherapist": 35000,
    "cook": 40000
}

def choose_job(player):
    if player.university == "yes":
        print("It is decision time", player.name)
        job_question = input("After attending a university, you can now decide what kind of job you want to do. Either a job for which you need a university degree or one for which you don't. Then a random profession is selected. A: Job with university degree, B: Job without university degree")
        if job_question == "A":
            randomjob = random.choice(list(university_jobs_dictionary))
            player.job = randomjob
            print("Your job will be: " + player.job)
            for key in university_jobs_dictionary:
                if key == randomjob:
                    randomsalary = university_jobs_dictionary[key]
                    player.salary = randomsalary
                    print (f"Your salary will be: {university_jobs_dictionary[key]}")   
        else:
            randomjob = random.choice(list(no_university_jobs_dictionary))
            player.job = randomjob
            print("Your job will be: " + player.job)
            for key in no_university_jobs_dictionary:
                if key == randomjob:
                    randomsalary = no_university_jobs_dictionary[key]
                    player.salary = randomsalary
                    print (f"Your salary will be: {no_university_jobs_dictionary[key]}")
     
    else:
        job_question = input("Player 1: Having not attended a university, you will have a random job that does not require a university degree. Ready? A: Yes B: No")
        if job_question == "A":
            randomjob = random.choice(list(no_university_jobs_dictionary))
            player.job = randomjob
            print("Your job will be: " + player.job)
            for key in no_university_jobs_dictionary:
                if key == randomjob:
                    randomsalary = no_university_jobs_dictionary[key]
                    player.salary = randomsalary
                    print (f"Your salary will be: {no_university_jobs_dictionary[key]}")
        else: 
            print("You have no choice. You have to do a job, otherwise life will be boring.")
            randomjob = random.choice(list(no_university_jobs_dictionary))
            player.job = randomjob
            print("Your job will be: " + player.job)
            for key in no_university_jobs_dictionary:
                if key == randomjob:
                    randomsalary = no_university_jobs_dictionary[key]
                    player.salary = randomsalary
                    print (f"Your salary will be: {no_university_jobs_dictionary[key]}")

# %%
# ALL ACTION FIELD DEFINITIONS


# Horse race
def q1 (player):
    print ("Your friends invite you to a horse race, you want to bet. How much are you willing to bet?")
    bet_amount = int(input())
    print("Alright. Your bet is", (bet_amount), ". Which horse will you bet on? Number 1, Number 2, Number 3 or Number 4. Please insert the Number you want to bet on.")
    bet_horses = [1, 2, 3, 4]
    bet_answer = int(input())
    winning_horse = random.choice(bet_horses)
    if bet_answer == winning_horse:
        horsebet_win = (10 * bet_amount)
        player.balance =+ (horsebet_win)
        print ("Your Horse has won. You win", (horsebet_win))
    else:
        player.balance -= (bet_amount)
        print ("You lose your", (bet_amount),".","Horse",(winning_horse),"has won")
    print("Youre balance is", player.balance)

# Finder's reward
def q2 (player):
    print("You find a silver suitcase in the street. Do you want to bring it to the police or take it home and open it. A: Bring it to the police B: Take it home and open it")
    answer_suitcase = input()
    if answer_suitcase == "A":
        print("You bring the suitcase to the police. After a few days a rich man contacts you. It was his suitcase. He gives you 10000 finder's fee.")
        player.balance += 10000
    else:
        print("You want to open the case. You have to enter a 4 digit pin. It seems like the owner of the suitcase is American. Maybe it is the year, when the declaration of independence was signed. Try your Luck!")
        pin_answer = input()
        if pin_answer == "1776":
            print ("You must be a genius. You opened the suitcase. You find 2000 Euros")
            player.balance += 2000
        else:
            print ("That is the false pin. The suitcase does not open anymore.")
        print("Your balance is", player.balance)
        
# Penalty for speeding           
def q13 (player):
    your_fine = 0
    print ("You got caught speeding! The policeman gives the following options. Either you roll your penalty and the number of dice is multiplied by 1000 or you pay 4000 euros.")
    print ("Do you want to roll the dice?")
    print ("A: Yes B: No")
    antwort3 = input()
    if antwort3 == "A":
        dice = random.randrange(1,7)
        your_fine = (1000 * dice)
        player.balance -= your_fine
        print ("You have rolled a", (dice),".", "You pay", (your_fine))
    else: 
        player.balance -= 4000
        print("You pay 400 Euros.")
    print("Your balance is", player.balance)
    
# Quizshow Final Question
def q4 (player):
    q_answer = input("You made it to last question in a quiz show. The prize money is 100,000 euros. All jokers are used up and you have no idea which answer option is the right one. You have two options: You can decide not to answer the final question and win 10,000 Euro. Alternatively, you can try to guess the last question. There are four different possible answers for the question. Which one do you choose? A: Take the 10,000 euros B: Try my luck and guess ")
    if q_answer == "A":
        player.balance += 10000
        print("You took the 10000 Euros.")
        print("Your balance is", player.balance)
    else:
        quiz_opportinities = ["A", "B", "C", "D"]
        right_answer = random.choice(quiz_opportinities)
        quiz_choice = input("Which answer do you think is the right one? A, B, C or D?")
        if right_answer == quiz_choice:
            print("Congratulations!!! You are right. You win 100000.")
            player.balance += 100000
            print("Your balance is", player.balance)
        else:
            print("Your answer was not correct. You leave the quiz show without prize money.")  
    
# The grandfather's illness
def q5 (player):
    print ("Your grandfather is very sick. Now you have to roll the dice. If the number is even, your grandfather dies and you inherit 100000 euros. On an odd number a medical miracle happens and your grandfather survives, but you have to pay 50000 for the medical bill")
    dice = random.randrange(1,7)
    print ("You have rolled a", (dice))
    if dice == (2, 4, 6):
        print ("Your grandpa dies, you inherit 10000 Euro")
        player.balance += 100000
    else:
        print ("You have to pay for the medical bill")
        player.balance -= 50000
    print("Your balance is", player.balance)

# Having a child I
def q6 (player):
    print("You are having a child. To be able to cover the costs for the next years, you put aside 30000 Euro.")
    player.balance -= 30000
    player.children += 1
    print("Your balance is", player.balance)
    
# Having a child II
def q3 (player):
    print("You are having a child. To be able to cover the costs for the next years, you put aside 30000 Euro.")
    player.balance -= 30000
    player.children += 1
    print("Your balance is", player.balance)
    
# Child wants to go to university
def q8 (player):
    print("Your child wants to go to college. For every child you have to pay tuition fees amounting to 30000 euros per child.")
    if player.children > 0:
        player.balance -= 30000 * player.children
        amount = player.children * 30000
        print("Amount of children:", player.children)
        print("The fee therefore amounts to", amount)
        print("Your balance is", player.balance)
    else:
        print("As you do not have a chield, no fees arise")
        print("Your balance is", player.balance)
    
# Marriage
def q9 (player):
    print("Congratulations. You are getting married. However, this is associated with 30000 euros in costs.")
    player.balance -= 30000
    print("Youre balance is", player.balance)
        
# Lotto
def q10 (player):
    q9_answer = input("You're thinking about playing the lottery. Chance to win: 10%. Price: 10000 EUR. Possible winning: 100000 EUR. How do you decide? A: I'll try my luck. B: No, thanks.")
    if q9_answer == "A":
        player.balance -= 10000
        print("You buy a ticket for 10000 EUR")
        choice = int(input("Choose a number between 1 and 10 on your lottery ticket"))
        result = random.choice(range(1,11))  
        if choice == result:
            print("Congratulations! You won 100000 EUR!")
            player.balance += 100000
            print("Your balance is", player.balance)
        else:
            print("You did not win the lottery")
            print("Your balance is", player.balance)
    else:
        print("You decided not to play the lottery. You're balance stays at", player.balance)
        
# Salary raise
def q11 (player):
    print("Congratulations. As a result of your excellent performance, your salary will be doubled.")
    player.salary = player.salary * 2
    player.balance += player.balance
    print("Your new salary is", player.salary)
    print("Your balance is", player.balance)

# Radio Quiz
def q12 (player):
    print("You participate in a radio quiz show and have the opportunity to win 20000 Euros. The host asks you: What is the most played christmas song world wide? A: Driving Home for Christmas B: Last Christmas C: All I want for Christmas")
    radio_quiz_answer = input()
    if radio_quiz_answer == "B":
        player.balance =+ 20000
        print("That was the right answer. You just won 20000 Euros")
    else:
        player.balance -= 0
        print("Unfortunately that was the false answer. Maybe you are lucky the next time.")
    print("Your balance is", player.balance)
    
# Casino
def q7 (player):
    print ("Your friends invite you to the casino to play Roulette. How much do you want to bet?")
    bet_amount = int(input())
    color_list = ["green","red","black"]
    print("Alright. Your bet is", (bet_amount), ". Do you want to bet on a color or a number? A: Color B: Number")
    color_or_number = input()
    if color_or_number == "A":
        print("Which color do you want to bet on? green, red or black. Please write the color you want to bet on.")
        random_color = random.choice(color_list)
        color_choice = input()
        if color_choice == random_color:
            if color_choice == "green":
                win_amount = bet_amount * 37
                player.balance += (win_amount)
            elif color_choice == "red":
                win_amount = bet_amount * 2
                player.balance += (win_amount)
            else:
                win_amount = bet_amount * 2
                player.balance += (win_amount)
            print("Wow, the winning color indeed is", (color_choice), ". You just won", (win_amount), "Euros.")
        else:
            print("The color", (random_color), "came. You just lost", (bet_amount), "Euros.")
            player.balance =- (bet_amount)
    else:
        print("Which number do you want to bet on? Please write a number between 0 and 36.")
        random_number = random.randrange(0,37)
        number_choice = int(input())
        if number_choice == random_number:
            win_amount = bet_amount * 37
            player.balance += (win_amount)
            print ("Number", (random_number), "came. You just won", (win_amount), "Euros.")
        else:
            print ("Number", (random_number), "came, You just lost", (bet_amount), "Euros.")
            player.balance -= (bet_amount)
    print("Your balance is", player.balance)

# Inheretance
def q14 (player):
    q8_answer = input("A close family member passed away. You are entitled to a portion of the inheritance. You don't know if you will inherit a positive or negative amount. Do you want to accept the inheritance? A: Yes B: No ")
    if q8_answer == "A":
        inheritance_opportinities = [-100000, 100000]
        inheritance = random.choice(inheritance_opportinities)
        player.balance += inheritance
        print("You inherit", inheritance, "EUR.")
        print("Your balance is", player.balance)
    else:
        print("You decided not to accept the inheritance. You're balance stays at", player.balance)

# Bonus payment
def q15 (player):
    print("Good job! Due to your outstanding performance this year your company decided to pay you a bonus in the amount of your annual salary")
    player.balance += player.salary
    print("Your balance is", player.balance)

# Police control
def q16 (player):
    q_answer = input("You were at a birthday party and consumed alcohol. Nevertheless, you decide to drive home. On the way home, you are stopped by the police. You are unsure whether your alcohol level is above or below the permitted limit. What are you doing? A: Try to make a u turn before the police check B: Get checked and hope that you are under the tolerance limit ")
    if q_answer == "A":
        print("The police officer notices your escape attempt, chases and catches you. A fine of 20,000 euros is due.")
        player.balance += 20000
        print("Your balance is", player.balance)
    else:
        print("During the police check, it came out that you were under the tolerance limit. The worry was completely in vain.")
        print("Your balance stays at", player.balance) 

# Vacation
def q17 (player):
    print("You are going on a trip around the world. The trip costs 30000 euros.")
    player.balance -= 30000
    print("Your balance is", player.balance)

# %%
import random
import time

# This is our dictionary of fields. The game loop accesses the different action fields (e.g.q5) when the player reaches a 
# specific field (e.g. 7). 
field_dic = {
    1: q1,
    2: q2,
    3: q3,
    4: q4,
    5: q5,
    6: q6,
    7: q7,
    8: q8,
    9: q9,
    10: q10,
    11: q11,
    12: q12,
    13: q5,
    14: q14,
    15: q15,
    16: q16,
    17: q17
}
# At the beginning of the game, the players can decide how many people are playing. Initially, all 4 instances of the player 
# class are created but only the amount of desired players are part of the following game loop
class player_creation:
    def __init__(self, number, name, field, balance, university, job, salary, children, turn):
        self.number = number
        self.name = name
        self.field = field
        self.balance = balance
        self.university = university
        self.job = job
        self.salary = salary
        self.children = children
        self.turn = turn
player_1 = player_creation(1, "Player", 0, 0, "tbd", "tbd", 0, 0, 0)
player_2 = player_creation(2, "Player", 0, 0, "tbd", "tbd", 0, 0, 0)
player_3 = player_creation(3, "Player", 0, 0, "tbd", "tbd", 0, 0, 0)
player_4 = player_creation(4, "Player", 0, 0, "tbd", "tbd", 0, 0, 0)

list_of_players = [player_1, player_2, player_3, player_4]


# At the beginning of the game, players enter their name, depending on the number of players they choose to play with
def naming_players(number_of_players):
    if number_of_players == 1:
        name_1 = input("Player 1, what is your name?")
        print("")
        player_1.name = name_1
    elif number_of_players == 2:
        player_1.name = input("Player 1, what is your name?")
        player_2.name = input("Player 2, what is your name?")
        print("")
    elif number_of_players == 3:
        player_1.name = input("Player 1, what is your name?")
        player_2.name = input("Player 2, what is your name?")
        player_3.name = input("Player 3, what is your name?")
        print("")
    elif number_of_players == 4:
        player_1.name = input("Player 1, what is your name?")
        player_2.name = input("Player 2, what is your name?")
        player_3.name = input("Player 3, what is your name?")
        player_4.name = input("Player 4, what is your name?")
        print("")
    

# Throwing the dice. Every player is assigned a random number that she advances on the board. 
def throw_dice(player):
    print("Its your turn,",player.name)
    random_number = random.randrange(1,4)
    player.field += random_number
    player.turn += 1
    print("You threw a", random_number, "!")

# This accesses the actual field action dictionary defined above
def field_action(player):
    field_dic[player.field](player)
    
# Every two rounds the players get their salary that is added to their balance
def pay_day(player):
    if (player.turn % 2) == 0 and player.job != "tbd":
        player.balance += player.salary
        print("It is Payday! Your balance will be updated by the amount of your salary:", player.salary)

# The start of the game comprises the selection of players and the naming of players
number_of_players = int(input("Hello players. Welcome to the Game of Life! How many people are playing? You can choose between 1-4"))
naming_players(number_of_players)
print("Great. Lets get started. The rules are easy. You throw the dice and land on a new field. An event happens and you will either profit of lose from it. Sometimes you will have to make decision as well. Good luck!")
print("")
time.sleep(2)

# At the end of the game every player receives their final balances and information about their achievements in life.
# The winner, the player with the highest balance, is then determined
def end_result():
    dic_of_balances = {}
    for player in list_of_players:
        if player.name != "Player":
            dic_of_balances[player.name] = player.balance
            print("Hey", player.name, "! Your final balance is", player.balance)
            print("As a", player.job,", you earned", player.salary, "EUR a year and had", player.children, "children.")
            print("")
    print("And the winner of the game is", max(dic_of_balances, key=dic_of_balances.get).upper(), "! Congratulations!")
    

# game loop. The while loop plays through every player until they reach the final field. Along the way, they make decisions
# and gain or lose money. The final loop ends when all players reach the final field and the winner is announced
end_game_counter = 0
while end_game_counter == 0:
    for player in list_of_players:
        if player.turn == 1:
            choose_education(player)
            player.turn += 1
            print("")
            time.sleep(4)
        elif player.turn == 2:
            choose_job(player)
            player.turn += 1
            print("")
            time.sleep(4)
        elif int(number_of_players) >= player.number and player.field <= 17:
            throw_dice(player)
            if player.field <= 17:
                field_action(player)
                pay_day(player)
            else:
                print("Congratulations, you managed to finished the game")
            print("")
            time.sleep(4)
        elif int(number_of_players) >= player.number and player.field > 17:
            print("Congratulations to everybody, this is the end of the game")
            end_result()
            end_game_counter += 1
            break
# Out:
# Hello players. Welcome to the Game of Life! How many people are playing? You can choose between 1-4 2
# Player 1, what is your name? Lisa
# Player 2, what is your name? Felix
# Great. Lets get started. The rules are easy. You throw the dice and land on a new field. An event happens and you will either profit of lose from it. Sometimes you will have to make decision as well. Good luck!
#
# Its your turn, Lisa
# You threw a 3 !
# You are having a child. To be able to cover the costs for the next years, you put aside 30000 Euro.
# Your balance is -30000
#
# Its your turn, Felix
# You threw a 3 !
# You are having a child. To be able to cover the costs for the next years, you put aside 30000 Euro.
# Your balance is -30000
#
# You have to make a choice now Lisa
# Do you want to go to university? A. yes, B: no A
# You have to make a choice now Felix
# Do you want to go to university? A. yes, B: no B
# It is decision time Lisa
# ...
